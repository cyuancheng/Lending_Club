# %% [markdown]
# # Machine Learning -classification <a class="tocSkip">

# %% [markdown]
# Build mechine learning model to predict the loan default

# %% [markdown]
# ## Library

# %%
# Load general utilities
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy

import datetime
import numpy as np
import pickle
import time
import seaborn as sns
import os
from IPython import get_ipython
ipython = get_ipython()
# Options for pandas
pd.options.display.max_columns = 50
pd.options.display.max_rows = 30

# Load sklearn utilities
import sklearn
from sklearn.model_selection import train_test_split, RepeatedStratifiedKFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, \
roc_auc_score, roc_curve, precision_recall_curve, auc, brier_score_loss, mean_squared_error, r2_score
from sklearn.calibration import calibration_curve

# Load classifiers
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import RidgeClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB, BernoulliNB
from sklearn.svm import SVC, LinearSVC
from sklearn.neighbors import KNeighborsClassifier

# Load debugger, if required
#import pixiedust
pd.options.mode.chained_assignment = None #'warn'

# %% [markdown]
# ## Import data

# %%
# read data
start = time.time()
path = '/Users/cyuancheng/Documents/course/Springboard/Capstone1/data/'
df = pd.read_csv(path+'LC_ML_prep.csv', low_memory=False, index_col=0, \
                 parse_dates=['issue_d', 'earliest_cr_line', 'last_pymnt_d'] )
end = time.time()
print('It takes  ' + str(round((end-start)/60, 1)) +' min to read the data')
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# It takes  1.0 min to read the data

# %%
# To ensure all the loans were matured, we only consider issue date before 2015 
df = df[df['issue_d']<'2015']

# %%
df.head()
# Out:
#   home_ownership verification_status             purpose addr_state  pub_rec  \
# 1       MORTGAGE        Not Verified  debt_consolidation         TX      0.0
# 2            OWN            Verified  debt_consolidation         MI      0.0
# 3           RENT        Not Verified  debt_consolidation         NC      0.0
# 5       MORTGAGE        Not Verified  debt_consolidation         CT      0.0
# 6           RENT        Not Verified  debt_consolidation         NC      1.0
#
#    term_num  grade_num  loan_period  int_rate  revol_util  loan_amnt  \
# 1        36          7    29.996509      7.62        55.7    12000.0
# 2        36          6    30.982156     10.99        61.2    27050.0
# 3        36          6    27.992361     10.99        24.0    12000.0
# 5        36          7    37.027454      6.62        21.6    12000.0
# 6        36          6    37.027454     12.85        81.9    14000.0
#
#    funded_amnt  installment  open_acc   fico   total_pymnt  log_annual_inc  \
# 1      12000.0       373.94      17.0  709.0  13397.539998        4.984527
# 2      27050.0       885.46      14.0  734.0  31752.530000        4.740363
# 3      12000.0       392.81      15.0  724.0  13988.609996        4.778151
# 5      12000.0       368.45      12.0  764.0  13263.954639        5.021189
# 6      14000.0       470.71       6.0  674.0  16945.318783        4.944483
#
#     log_dti  log_revol_bal  log_delinq_2yrs  emp_length_num  Log_Annual_ROI  \
# 1  1.100715       4.122150             -inf             3.0       -1.346243
# 2  1.359266       4.563932             -inf            10.0       -1.193486
# 3  0.664642       3.853516             -inf             4.0       -1.167860
# 5  1.147676       4.119520             -inf            10.0       -1.481653
# 6  1.000868       3.566555              0.0             4.0       -1.194953
#
#      issue_d earliest_cr_line last_pymnt_d  target
# 1 2013-12-01       2003-09-01   2016-06-01       0
# 2 2013-12-01       1986-10-01   2016-07-01       0
# 3 2013-12-01       2009-12-01   2016-04-01       0
# 5 2013-12-01       1994-03-01   2017-01-01       0
# 6 2013-12-01       1988-06-01   2017-01-01       0

# %%
df.shape
# Out:
# (286170, 29)

# %% [markdown]
# It is computationally expensive to run ML models on this dataset. So we decide to take a small sample of this dataset.

# %%
# resample data (20%)
df_sam=df.sample(frac=0.2, replace=False, random_state=42)

# %%
df_sam.shape
# Out:
# (57234, 29)

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# #### 1. datetime
# Converting the datetime columns into integer number of year and month

# %%
col_dt = df_sam.select_dtypes('datetime64').columns
print(col_dt)
print('number of datetime features =', len(col_dt))
# Out:
# Index(['issue_d', 'earliest_cr_line', 'last_pymnt_d'], dtype='object')
# number of datetime features = 3

# %%
df_sam['issue_y']=pd.to_datetime(df_sam['issue_d']).apply(lambda x: int(x.strftime('%Y')))
df_sam['issue_m']=pd.to_datetime(df_sam['issue_d']).apply(lambda x: int(x.strftime('%m')))
df_sam['earliest_cr_line_y']=pd.to_datetime(df_sam['earliest_cr_line']).apply(lambda x: int(x.strftime('%Y')))
df_sam['earliest_cr_line_m']=pd.to_datetime(df_sam['earliest_cr_line']).apply(lambda x: int(x.strftime('%m')))
df_sam['last_pymnt_y']=pd.to_datetime(df_sam['last_pymnt_d']).apply(lambda x: int(x.strftime('%Y')))
df_sam['last_pymnt_m']=pd.to_datetime(df_sam['last_pymnt_d']).apply(lambda x: int(x.strftime('%m')))

# %%
# drop datetime columns
df_sam.drop(col_dt, axis=1, inplace=True)

# %% [markdown]
# #### 2. Categorical variable
# one-hot encoding

# %%
col_cat = df_sam.select_dtypes('object').columns
print(col_cat)
print('number of categorical features =', len(col_cat))
# Out:
# Index(['home_ownership', 'verification_status', 'purpose', 'addr_state'], dtype='object')
# number of categorical features = 4

# %%
#one-hot encoding
df_cat = pd.get_dummies(df_sam[col_cat],dummy_na=True)
df_cat.head()
# Out:
#         home_ownership_MORTGAGE  home_ownership_OTHER  home_ownership_OWN  \
# 166897                        1                     0                   0
# 202386                        0                     0                   0
# 180791                        1                     0                   0
# 365860                        1                     0                   0
# 163887                        0                     0                   0
#
#         home_ownership_RENT  home_ownership_nan  \
# 166897                    0                   0
# 202386                    1                   0
# 180791                    0                   0
# 365860                    0                   0
# 163887                    1                   0
#
#         verification_status_Not Verified  verification_status_Source Verified  \
# 166897                                 1                                    0
# 202386                                 1                                    0
# 180791                                 0                                    0
# 365860                                 0                                    1
# 163887                                 1                                    0
#
#         verification_status_Verified  verification_status_nan  purpose_car  \
# 166897                             0                        0            0
# 202386                             0                        0            0
# 180791                             1                        0            0
# 365860                             0                        0            0
# 163887                             0                        0            0
#
#         purpose_credit_card  purpose_debt_consolidation  \
# 166897                    1                           0
# 202386                    0                           1
# 180791                    0                           1
# 365860                    0                           1
# 163887                    0                           1
#
#         purpose_home_improvement  purpose_house  purpose_major_purchase  \
# 166897                         0              0                       0
# 202386                         0              0                       0
# 180791                         0              0                       0
# 365860                         0              0                       0
# 163887                         0              0                       0
#
#         purpose_medical  purpose_moving  purpose_other  \
# 166897                0               0              0
# 202386                0               0              0
# 180791                0               0              0
# 365860                0               0              0
# 163887                0               0              0
#
#         purpose_renewable_energy  purpose_small_business  purpose_vacation  \
# 166897                         0                       0                 0
# 202386                         0                       0                 0
# 180791                         0                       0                 0
# 365860                         0                       0                 0
# 163887                         0                       0                 0
#
#         purpose_wedding  purpose_nan  addr_state_AK  addr_state_AL  ...  \
# 166897                0            0              0              0  ...
# 202386                0            0              0              0  ...
# 180791                0            0              0              0  ...
# 365860                0            0              0              0  ...
# 163887                0            0              0              0  ...
#
#         addr_state_MT  addr_state_NC  addr_state_NE  addr_state_NH  \
# 166897              0              0              0              0
# 202386              0              0              0              0
# 180791              0              0              0              0
# 365860              0              0              0              0
# 163887              0              0              0              0
#
#         addr_state_NJ  addr_state_NM  addr_state_NV  addr_state_NY  \
# 166897              0              0              0              0
# 202386              0              0              0              0
# 180791              0              0              0              0
# 365860              0              0              0              0
# 163887              0              0              0              0
#
#         addr_state_OH  addr_state_OK  addr_state_OR  addr_state_PA  \
# 166897              0              0              0              0
# 202386              0              0              0              0
# 180791              0              0              0              0
# 365860              0              0              0              0
# 163887              0              0              0              0
#
#         addr_state_RI  addr_state_SC  addr_state_SD  addr_state_TN  \
# 166897              0              0              0              0
# 202386              0              0              0              0
# 180791              0              0              0              0
# 365860              0              0              0              0
# 163887              0              0              0              0
#
#         addr_state_TX  addr_state_UT  addr_state_VA  addr_state_VT  \
# 166897              0              0              0              0
# 202386              0              0              0              0
# 180791              0              0              0              0
# 365860              1              0              0              0
# 163887              0              0              0              0
#
#         addr_state_WA  addr_state_WI  addr_state_WV  addr_state_WY  \
# 166897              0              0              0              0
# 202386              0              0              0              0
# 180791              0              1              0              0
# 365860              0              0              0              0
# 163887              0              0              0              0
#
#         addr_state_nan
# 166897               0
# 202386               0
# 180791               0
# 365860               0
# 163887               0
#
# [5 rows x 72 columns]

# %% [markdown]
# #### 3. Numerical variable

# %%
col_num = df_sam.select_dtypes('float').columns 
print(col_num)
print('number of numerical feature =', len(col_num))
# Out:
# Index(['pub_rec', 'loan_period', 'int_rate', 'revol_util', 'loan_amnt',
#        'funded_amnt', 'installment', 'open_acc', 'fico', 'total_pymnt',
#        'log_annual_inc', 'log_dti', 'log_revol_bal', 'log_delinq_2yrs',
#        'emp_length_num', 'Log_Annual_ROI'],
#       dtype='object')
# number of numerical feature = 16

# %%
col_int = df_sam.select_dtypes('int64').columns 
print(col_int)
# Out:
# Index(['term_num', 'grade_num', 'target', 'issue_y', 'issue_m',
#        'earliest_cr_line_y', 'earliest_cr_line_m', 'last_pymnt_y',
#        'last_pymnt_m'],
#       dtype='object')

# %%
df_num = pd.concat((df_sam[col_num], df_sam[col_int]),axis=1)
df_num.drop(['log_delinq_2yrs'], axis=1, inplace=True) # drop this feature, because it contains infinity.
df_num.head()
# Out:
#         pub_rec  loan_period  int_rate  revol_util  loan_amnt  funded_amnt  \
# 166897      0.0    35.976098      9.76        68.0     6400.0       6400.0
# 202386      0.0    36.008953      6.99        48.5    12000.0      12000.0
# 180791      0.0    11.992033     15.99        19.4     8800.0       8800.0
# 365860      0.0    11.072096     12.99        46.3     5500.0       5500.0
# 163887      0.0    20.961416      7.62        22.9     4325.0       4325.0
#
#         installment  open_acc   fico   total_pymnt  log_annual_inc   log_dti  \
# 166897       205.79       8.0  694.0   7408.430000        4.477121  1.244277
# 202386       370.48      10.0  709.0  13329.902695        4.568202  1.395326
# 180791       309.34      18.0  759.0   9979.690000        4.812913  1.356217
# 365860       185.30      10.0  714.0   6083.390000        4.342423  1.143327
# 163887       134.78       8.0  749.0   4752.709207        4.371680  0.666518
#
#         log_revol_bal  emp_length_num  Log_Annual_ROI  term_num  grade_num  \
# 166897       3.858056             4.0       -1.300886        36          6
# 202386       3.881670             3.0       -1.447985        36          7
# 180791       4.010258             6.0       -0.872408        36          4
# 365860       3.726564            10.0       -0.937586        36          6
# 163887       3.576572             6.0       -1.255940        36          7
#
#         target  issue_y  issue_m  earliest_cr_line_y  earliest_cr_line_m  \
# 166897       0     2012        5                2001                  12
# 202386       0     2014       11                2007                   8
# 180791       0     2014       12                2002                   9
# 365860       0     2014        3                2000                   9
# 163887       0     2012        6                2000                  11
#
#         last_pymnt_y  last_pymnt_m
# 166897          2015             5
# 202386          2017            11
# 180791          2015            12
# 365860          2015             2
# 163887          2014             3

# %%
df_num.shape
# Out:
# (57234, 24)

# %% [markdown]
# ### Feature Selection
#
# #### 1. Eliminate correlated features
#
# - From the Pearson correlation heatmap, we found that for prediction on default as target, the annual ROI is the most predicative of all features, followed by grade, and interest rate; while total payment has negative impact.
# - To avoid overfitting, we eliminated the features that are highly correlated with each other, and only keep the following features.  (multicollinearity)

# %% [markdown]
# #### - Eliminate feature that is uncorrelated with target

# %%
#Correlation with output variable
cor = df_num.corr()
cor_target = abs(cor["target"])

# only keep correlation >0.01 with target
relevant_features = cor_target[cor_target>0.01] 
relevant_features.sort_values(ascending=False)
# Out:
# target                1.000000
# Log_Annual_ROI        0.213876
# grade_num             0.146531
# int_rate              0.145226
# total_pymnt           0.141115
# term_num              0.125457
# fico                  0.068241
# log_dti               0.062230
# funded_amnt           0.055441
# loan_amnt             0.055393
# loan_period           0.055132
# log_annual_inc        0.044957
# last_pymnt_y          0.033721
# revol_util            0.032115
# installment           0.025971
# open_acc              0.025285
# earliest_cr_line_y    0.022840
# issue_y               0.020933
# emp_length_num        0.013431
# pub_rec               0.012252
# log_revol_bal         0.011038
# Name: target, dtype: float64

# %%
# list relevant features
list_feature = relevant_features.to_frame().index.to_list()
print(list_feature)
# Out:
# ['pub_rec', 'loan_period', 'int_rate', 'revol_util', 'loan_amnt', 'funded_amnt', 'installment', 'open_acc', 'fico', 'total_pymnt', 'log_annual_inc', 'log_dti', 'log_revol_bal', 'emp_length_num', 'Log_Annual_ROI', 'term_num', 'grade_num', 'target', 'issue_y', 'earliest_cr_line_y', 'last_pymnt_y']

# %% [markdown]
# #### - Eliminate feature that is higly correlated with each other (multicollinearity)

# %%
# heatmap

plt.figure(figsize=(20,20))

ax = sns.heatmap(
    df_num[list_feature].corr(), 
    vmin=-1, vmax=1, center=0,annot = True,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %% [markdown]
# remove funded_amnt, installment, total_paymnt, grade_num, last_pymnt_y

# %%
list_feature.remove('funded_amnt')
list_feature.remove('installment')
list_feature.remove('total_pymnt')
list_feature.remove('grade_num')
list_feature.remove('last_pymnt_y')

# %%
list_feature
# Out:
# ['pub_rec',
#  'loan_period',
#  'int_rate',
#  'revol_util',
#  'loan_amnt',
#  'open_acc',
#  'fico',
#  'log_annual_inc',
#  'log_dti',
#  'log_revol_bal',
#  'emp_length_num',
#  'Log_Annual_ROI',
#  'term_num',
#  'target',
#  'issue_y',
#  'earliest_cr_line_y']

# %%
# combine numerical variable and categorical variable
df_feature = pd.concat((df_sam[list_feature], df_cat),axis=1)
df_feature.drop(['target'], axis=1, inplace=True) 
df_feature.head()
# Out:
#         pub_rec  loan_period  int_rate  revol_util  loan_amnt  open_acc  \
# 166897      0.0    35.976098      9.76        68.0     6400.0       8.0
# 202386      0.0    36.008953      6.99        48.5    12000.0      10.0
# 180791      0.0    11.992033     15.99        19.4     8800.0      18.0
# 365860      0.0    11.072096     12.99        46.3     5500.0      10.0
# 163887      0.0    20.961416      7.62        22.9     4325.0       8.0
#
#          fico  log_annual_inc   log_dti  log_revol_bal  emp_length_num  \
# 166897  694.0        4.477121  1.244277       3.858056             4.0
# 202386  709.0        4.568202  1.395326       3.881670             3.0
# 180791  759.0        4.812913  1.356217       4.010258             6.0
# 365860  714.0        4.342423  1.143327       3.726564            10.0
# 163887  749.0        4.371680  0.666518       3.576572             6.0
#
#         Log_Annual_ROI  term_num  issue_y  earliest_cr_line_y  \
# 166897       -1.300886        36     2012                2001
# 202386       -1.447985        36     2014                2007
# 180791       -0.872408        36     2014                2002
# 365860       -0.937586        36     2014                2000
# 163887       -1.255940        36     2012                2000
#
#         home_ownership_MORTGAGE  home_ownership_OTHER  home_ownership_OWN  \
# 166897                        1                     0                   0
# 202386                        0                     0                   0
# 180791                        1                     0                   0
# 365860                        1                     0                   0
# 163887                        0                     0                   0
#
#         home_ownership_RENT  home_ownership_nan  \
# 166897                    0                   0
# 202386                    1                   0
# 180791                    0                   0
# 365860                    0                   0
# 163887                    1                   0
#
#         verification_status_Not Verified  verification_status_Source Verified  \
# 166897                                 1                                    0
# 202386                                 1                                    0
# 180791                                 0                                    0
# 365860                                 0                                    1
# 163887                                 1                                    0
#
#         verification_status_Verified  verification_status_nan  purpose_car  \
# 166897                             0                        0            0
# 202386                             0                        0            0
# 180791                             1                        0            0
# 365860                             0                        0            0
# 163887                             0                        0            0
#
#         ...  addr_state_MT  addr_state_NC  addr_state_NE  addr_state_NH  \
# 166897  ...              0              0              0              0
# 202386  ...              0              0              0              0
# 180791  ...              0              0              0              0
# 365860  ...              0              0              0              0
# 163887  ...              0              0              0              0
#
#         addr_state_NJ  addr_state_NM  addr_state_NV  addr_state_NY  \
# 166897              0              0              0              0
# 202386              0              0              0              0
# 180791              0              0              0              0
# 365860              0              0              0              0
# 163887              0              0              0              0
#
#         addr_state_OH  addr_state_OK  addr_state_OR  addr_state_PA  \
# 166897              0              0              0              0
# 202386              0              0              0              0
# 180791              0              0              0              0
# 365860              0              0              0              0
# 163887              0              0              0              0
#
#         addr_state_RI  addr_state_SC  addr_state_SD  addr_state_TN  \
# 166897              0              0              0              0
# 202386              0              0              0              0
# 180791              0              0              0              0
# 365860              0              0              0              0
# 163887              0              0              0              0
#
#         addr_state_TX  addr_state_UT  addr_state_VA  addr_state_VT  \
# 166897              0              0              0              0
# 202386              0              0              0              0
# 180791              0              0              0              0
# 365860              1              0              0              0
# 163887              0              0              0              0
#
#         addr_state_WA  addr_state_WI  addr_state_WV  addr_state_WY  \
# 166897              0              0              0              0
# 202386              0              0              0              0
# 180791              0              1              0              0
# 365860              0              0              0              0
# 163887              0              0              0              0
#
#         addr_state_nan
# 166897               0
# 202386               0
# 180791               0
# 365860               0
# 163887               0
#
# [5 rows x 87 columns]

# %%
# set X, y
X=df_feature 
y=df_sam['target']

# %% [markdown]
# ### Train test split
#
# Split into test and train sets BEFORE oversampling

# %%
# setting up testing and training sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=27)

# %%
# Standarization (before resampling)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ### Oversampling by SMOTE
# - Oversampling the training set using Synthetic Minority Oversampling Technique ([SMOTE](https://imbalanced-learn.readthedocs.io/en/stable/generated/imblearn.over_sampling.SMOTE.html))
# - Standarization after SMOTE
#  - fit_transform on training data, transform on test data

# %%
# load imbalanced-learn
from imblearn.over_sampling import SMOTE

# %%
start = time.time()
sm = SMOTE(random_state=42)
X_train_res, y_train_res = sm.fit_sample(X_train, y_train)
end= time.time()
print('It takes  ' + str(round((end-start), 1)) +' sec')
# Out:
# It takes  3.8 sec

# %%
# Standarization (after resampling)
scaler = StandardScaler()
X_train_res = scaler.fit_transform(X_train_res)
X_test = scaler.transform(X_test)

# %%
# without oversampling
values, counts = np.unique(y_train, return_counts=True)
print(values, counts)
# Out:
# [0 1] [41479  4308]

# %%
# after oversampling
values, counts = np.unique(y_train_res, return_counts=True)
print(values, counts)
# Out:
# [0 1] [41479 41479]

# %% [markdown]
# ### Learning Curve
# Use the learning curve to see how the select model learning with increasing the sample size. Use Logestic Regression as an example

# %%
import numpy as np
from sklearn.svm import SVC
from sklearn.model_selection import learning_curve
from sklearn.model_selection import ShuffleSplit

def plot_learning_curve(estimator, title, X, y, cv=None,
                        n_jobs=1, train_sizes=np.linspace(.1, 1.0, 5)):
    plt.rcParams.update({'font.size': 12})
    plt.figure(figsize=(8,5))
    plt.title(title)
    #plt.ylim(ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score (AUC)")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes, scoring='roc_auc')
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    
    plt.grid()
    
    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")
    plt.legend(loc="best")
    return plt

# %%
X, y = X_train_res[:12000], y_train_res[:12000]
title = "Learning Curves (Logistic Regression)"
# Cross validation with 100 iterations to get smoother mean train and validation set
# score curves, each time with 1/10 data randomly selected as a validation set.
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=42)
plot_learning_curve(LogisticRegression(), title, X, y, cv=cv, n_jobs=4)
plt.show()

# %% [markdown]
# ### Model evaluation function
# - use stratified k fold cross validation to avoid overfit
# - use confusion matrix and auc_ruc to evaluate model performance
# - model selection: baseline, logistic regression, svm, naive bayes, random forest, booster

# %%
def evaluation_model(model, X_train, y_train, X_test, y_test, train=True):
    target_names = ['Non-Defaulted Loan','Defaulted Loan']
    if train:
        X_pred = model.predict(X_train)
        print("Train Result:\n")
        print("Confusion Matrix: \n {}\n".format(confusion_matrix(y_train, X_pred)))
        print("Accuracy Score: {0:.4f}\n".format(accuracy_score(y_train,  X_pred)))
        print("Classification Report: \n {}\n".format(classification_report(y_train, X_pred, \
                                                                            target_names=target_names)))
        #cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=42)
        res_auc = cross_val_score(model, X_train, y_train, cv=10, scoring='roc_auc')
        
        print("Repeated Stratified KFold Cross Validation:\n")
        print("Mean AUC (cv): \t {0:.4f}".format(np.mean(res_auc)))
        print("SD AUC: \t\t {0:.4f}".format(np.std(res_auc)))
        
    elif train==False:
        y_pred = model.predict(X_test)
        print("Test Result:\n")        
        print("accuracy score: {0:.4f}\n".format(accuracy_score(y_test, y_pred)))
        print("Classification Report: \n {}\n".format(classification_report(y_test, y_pred,\
                                                                           target_names=target_names)))
        print("Confusion Matrix: \n {}\n".format(confusion_matrix(y_test, y_pred)))    
    return res_auc

# %% [markdown]
# ####  ROC Curve plot function
# We have used this function to plot ROC Curve for all the models.

# %%
def auc_ruc(X_test, y_test, title, model):
    fpr, tpr, thresholds = roc_curve(y_test, model.predict_proba(X_test)[:,1])
    auc=roc_auc_score(y_test,model.predict_proba(X_test)[:,1])
    print('AUC=', auc)
    plt.rcParams.update({'font.size': 12})
    plt.figure(figsize=(5,5))
    plt.title(title)
    plt.plot(fpr, tpr, 'r', lw=2,\
             label='AUC = %0.2f'% auc )
    plt.legend(loc='lower right')
    plt.plot([0,1],[0,1],'g--', lw=2)
    plt.xlim([0,1])
    plt.ylim([0,1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

# %%
def auc_ruc_res(X_test, y_test, model, model_res):
    fpr, tpr, thresholds = roc_curve(y_test, model.predict_proba(X_test)[:,1],
                                         pos_label=1)
    fpr_res, tpr_res, thresholds_res = roc_curve(y_test, model_res.predict_proba(X_test)[:,1],
                                         pos_label=1)
    auc=roc_auc_score(y_test,model.predict_proba(X_test)[:,1])
    auc_res=roc_auc_score(y_test,model_res.predict_proba(X_test)[:,1])
    print('AUC=',auc)
    print('AUC_rec=', auc_res)
    plt.rcParams.update({'font.size': 12})
    plt.figure(figsize=(5,5))
    plt.title('Receiver Operating Characteristic')
    plt.plot(fpr, tpr, 'b', \
             label='AUC (imbalance data) = %0.2f'% auc )
    plt.plot(fpr_res, tpr_res, 'r', \
             label='AUC (SMOTE) = %0.2f'% auc_res )
    plt.legend(loc='lower right')
    plt.plot([0,1],[0,1],'g--')
    plt.xlim([0,1])
    plt.ylim([0,1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

# %% [markdown]
# ## Model
# ### Baseline model (DummyClassifier)
# - Use a baseline model to evaluate and compare the model performance.
# - use [DummyClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.dummy.DummyClassifier.html) to predict the majority class in the data

# %%
# define the reference model
from sklearn.dummy import DummyClassifier

model_baseline = DummyClassifier(strategy='stratified')
model_baseline_res = DummyClassifier(strategy='stratified')

# %% [markdown]
# __without SMOTE__

# %%
model_baseline.fit(X_train, y_train)
evaluation_model(model_baseline, X_train, y_train, X_test, y_test, train=True)
# Out:
# Train Result:
#
# Confusion Matrix:
#  [[37467  4012]
#  [ 3903   405]]
#
# Accuracy Score: 0.8271
#
# Classification Report:
#                      precision    recall  f1-score   support
#
# Non-Defaulted Loan       0.91      0.90      0.90     41479
#     Defaulted Loan       0.09      0.09      0.09      4308
#
#           accuracy                           0.83     45787
#          macro avg       0.50      0.50      0.50     45787
#       weighted avg       0.83      0.83      0.83     45787
#
#
# Repeated Stratified KFold Cross Validation:
#
# Mean AUC (cv): 	 0.5027
# SD AUC: 		 0.0074
# array([0.5174425 , 0.4925984 , 0.50868923, 0.50686575, 0.49482797,
#        0.5005532 , 0.4928694 , 0.50540019, 0.50146498, 0.50587627])

# %% [markdown]
# __with SMOTE__

# %%
model_baseline_res.fit(X_train_res, y_train_res)
evaluation_model(model_baseline_res, X_train_res, y_train_res, X_test, y_test, train=True)
# Out:
# Train Result:
#
# Confusion Matrix:
#  [[20684 20795]
#  [20801 20678]]
#
# Accuracy Score: 0.4986
#
# Classification Report:
#                      precision    recall  f1-score   support
#
# Non-Defaulted Loan       0.50      0.50      0.50     41479
#     Defaulted Loan       0.50      0.50      0.50     41479
#
#           accuracy                           0.50     82958
#          macro avg       0.50      0.50      0.50     82958
#       weighted avg       0.50      0.50      0.50     82958
#
#
# Repeated Stratified KFold Cross Validation:
#
# Mean AUC (cv): 	 0.4984
# SD AUC: 		 0.0051
# array([0.4963838 , 0.4927676 , 0.4903568 , 0.50458052, 0.50156702,
#        0.49951784, 0.50518322, 0.50397782, 0.49572052, 0.49367056])

# %%
auc_ruc_res(X_test, y_test, model_baseline, model_baseline_res)
# Out:
# AUC= 0.5
# AUC_rec= 0.5

# %% [markdown]
# ### Logistic Regression

# %% [markdown]
# __without SMOTE__

# %%
logisticModel_0 = LogisticRegression()
logisticModel_0.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
scores_LR = evaluation_model(logisticModel_0, X_train, y_train, X_test, y_test, train=True)
# Out:
# Train Result:
#
# Confusion Matrix:
#  [[41479     0]
#  [ 4167   141]]
#
# Accuracy Score: 0.9090
#
# Classification Report:
#                      precision    recall  f1-score   support
#
# Non-Defaulted Loan       0.91      1.00      0.95     41479
#     Defaulted Loan       1.00      0.03      0.06      4308
#
#           accuracy                           0.91     45787
#          macro avg       0.95      0.52      0.51     45787
#       weighted avg       0.92      0.91      0.87     45787
#
#
# Repeated Stratified KFold Cross Validation:
#
# Mean AUC (cv): 	 0.6844
# SD AUC: 		 0.0144

# %% [markdown]
# __with SMOTE__

# %%
logisticModel_res = LogisticRegression()
logisticModel_res.fit(X_train_res,y_train_res)
# Out:
# LogisticRegression()

# %%
scores_LR_res = evaluation_model(logisticModel_res, X_train_res, y_train_res, X_test, y_test, train=True)
# Out:
# Train Result:
#
# Confusion Matrix:
#  [[27486 13993]
#  [13148 28331]]
#
# Accuracy Score: 0.6728
#
# Classification Report:
#                      precision    recall  f1-score   support
#
# Non-Defaulted Loan       0.68      0.66      0.67     41479
#     Defaulted Loan       0.67      0.68      0.68     41479
#
#           accuracy                           0.67     82958
#          macro avg       0.67      0.67      0.67     82958
#       weighted avg       0.67      0.67      0.67     82958
#
#
# Repeated Stratified KFold Cross Validation:
#
# Mean AUC (cv): 	 0.7348
# SD AUC: 		 0.0066

# %%
auc_ruc_res(X_test, y_test, logisticModel_0, logisticModel_res)
# Out:
# AUC= 0.7068871957570588
# AUC_rec= 0.712890895253909

# %% [markdown]
# ### Logistic Regression (Grid Search)
#
# Use random grid search to do hyperparameter tuning and to minimize false negatives.

# %%
from sklearn.model_selection import GridSearchCV
def cv_best_parameters(model, param_grid):
    cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=42)
    grid = GridSearchCV(model, param_grid,cv=cv, scoring='roc_auc')
    X=X_train_res
    y=y_train_res
    grid.fit(X,y)
    return grid.best_params_, grid.best_score_,grid.best_estimator_

# %%
# hyperparameter tuning
logreg_cv = LogisticRegression(random_state=0)
c=[0.001, 0.01, 0.1, 1, 10, 100, 1000]
param_grid = dict(C=c)
Best_params, Best_AUC, Best_classifier = cv_best_parameters(logreg_cv,param_grid)
print("Best AUC = "+ str(Best_AUC))
print(Best_classifier)
# Out:
# Best AUC = 0.7348443475651136
# LogisticRegression(C=100, random_state=0)

# %%
clf_LR = LogisticRegression(C=Best_classifier.C)
clf_LR.fit(X_train_res,y_train_res)

scores_LR = evaluation_model(clf_LR, X_train_res, y_train_res, X_test, y_test, train=True)
# Out:
# Train Result:
#
# Confusion Matrix:
#  [[27486 13993]
#  [13149 28330]]
#
# Accuracy Score: 0.6728
#
# Classification Report:
#                      precision    recall  f1-score   support
#
# Non-Defaulted Loan       0.68      0.66      0.67     41479
#     Defaulted Loan       0.67      0.68      0.68     41479
#
#           accuracy                           0.67     82958
#          macro avg       0.67      0.67      0.67     82958
#       weighted avg       0.67      0.67      0.67     82958
#
#
# Repeated Stratified KFold Cross Validation:
#
# Mean AUC (cv): 	 0.7348
# SD AUC: 		 0.0066

# %%
auc_ruc(X_test, y_test, 'ROC curve (Logistic Regression)',clf_LR)
# Out:
# AUC= 0.712890895253909

# %% [markdown]
# ### Naive Bayes (Grid Search)

# %%
# hyperparameter tuning
NaiveBayes_cv = BernoulliNB()
alpha=[0.1, 0.5,1]
param_grid = dict(alpha=alpha)
Best_params, Best_AUC, Best_classifier = cv_best_parameters(NaiveBayes_cv,param_grid)
print("Best AUC = "+ str(Best_AUC))
print(Best_classifier)
# Out:
# Best AUC = 0.730389135316571
# BernoulliNB(alpha=0.1)

# %%
clf_NB = BernoulliNB(alpha=Best_classifier.alpha)
clf_NB.fit(X_train_res,y_train_res)

scores_NB= evaluation_model(clf_NB , X_train_res, y_train_res, X_test, y_test, train=True)
# Out:
# Train Result:
#
# Confusion Matrix:
#  [[27549 13930]
#  [12622 28857]]
#
# Accuracy Score: 0.6799
#
# Classification Report:
#                      precision    recall  f1-score   support
#
# Non-Defaulted Loan       0.69      0.66      0.67     41479
#     Defaulted Loan       0.67      0.70      0.68     41479
#
#           accuracy                           0.68     82958
#          macro avg       0.68      0.68      0.68     82958
#       weighted avg       0.68      0.68      0.68     82958
#
#
# Repeated Stratified KFold Cross Validation:
#
# Mean AUC (cv): 	 0.7304
# SD AUC: 		 0.0063

# %%
auc_ruc(X_test, y_test, 'ROC curve (Naive Bayes)', clf_NB)
# Out:
# AUC= 0.7131560885841708

# %% [markdown]
# ### K Nearest Neighbors (Grid Search)

# %%
# hyperparameter tuning
start = time.time()
knn_cv = KNeighborsClassifier()
k_range = [5,10,20]
param_grid = dict(n_neighbors=k_range)

grid = GridSearchCV(knn_cv, param_grid, cv=10, scoring='roc_auc')
grid.fit(X_train_res, y_train_res)

Best_classifier = grid.best_score_
print("Best AUC = "+ str(grid.best_score_))
print(Best_classifier)
end=time.time()
print('It takes  ' + str(round((end-start)/60, 1)) +' min')
# Out:
# Best AUC = 0.9687897665545581
# 0.9687897665545581
# It takes  96.9 min

# %%
print(grid.best_params_, grid.best_score_,grid.best_estimator_)
# Out:
# {'n_neighbors': 10} 0.9687897665545581 KNeighborsClassifier(n_neighbors=10)

# %%
clf_knn = grid.best_estimator_
clf_knn.fit(X_train_res,y_train_res)

scores_knn= evaluation_model(clf_knn , X_train_res, y_train_res, X_test, y_test, train=True)
# Out:
# Train Result:
#
# Confusion Matrix:
#  [[31963  9516]
#  [  122 41357]]
#
# Accuracy Score: 0.8838
#
# Classification Report:
#                      precision    recall  f1-score   support
#
# Non-Defaulted Loan       1.00      0.77      0.87     41479
#     Defaulted Loan       0.81      1.00      0.90     41479
#
#           accuracy                           0.88     82958
#          macro avg       0.90      0.88      0.88     82958
#       weighted avg       0.90      0.88      0.88     82958
#
#
# Repeated Stratified KFold Cross Validation:
#
# Mean AUC (cv): 	 0.9674
# SD AUC: 		 0.0016

# %%
auc_ruc(X_test, y_test, 'ROC curve (K Nearest Neighbors)', clf_knn)
# Out:
# AUC= 0.6957506914698696

# %% [markdown]
# ### Random Forest (Grid Search)

# %%
RF_cv = RandomForestClassifier(random_state=42)

n_estimators = [10,20,50,100,200]

param_grid = dict(n_estimators=n_estimators)

Best_params, Best_AUC, Best_classifier = cv_best_parameters(RF_cv,param_grid)
print("Best AUC = "+ str(Best_AUC))
print(Best_classifier)
# Out:
# Best AUC = 0.9994495465769122
# RandomForestClassifier(n_estimators=200, random_state=42)

# %%
clf_RF = RandomForestClassifier(n_estimators=200, random_state=42)
clf_RF.fit(X_train_res,y_train_res)

scores_RF= evaluation_model(clf_RF , X_train_res, y_train_res, X_test, y_test, train=True)
# Out:
# Train Result:
#
# Confusion Matrix:
#  [[41479     0]
#  [    0 41479]]
#
# Accuracy Score: 1.0000
#
# Classification Report:
#                      precision    recall  f1-score   support
#
# Non-Defaulted Loan       1.00      1.00      1.00     41479
#     Defaulted Loan       1.00      1.00      1.00     41479
#
#           accuracy                           1.00     82958
#          macro avg       1.00      1.00      1.00     82958
#       weighted avg       1.00      1.00      1.00     82958
#
#
# Repeated Stratified KFold Cross Validation:
#
# Mean AUC (cv): 	 0.9995
# SD AUC: 		 0.0014

# %%
auc_ruc(X_test, y_test, 'ROC curve (Random Forest)', clf_RF)
# Out:
# AUC= 0.9763019989903552

# %% [markdown]
# #### Feature importance

# %%
plt.rcParams.update({'font.size': 12})
plt.figure(figsize=(8,5))
feat_importances = pd.Series(clf_RF.feature_importances_, \
                             index=df_feature.columns)
feat_importances.nlargest(12).sort_values(ascending=True).plot(kind='barh')
plt.title('Feature Importance (Random Forest)')
plt.xlabel('Normalized Gini Importance')
# Out:
# Text(0.5, 0, 'Normalized Gini Importance')

# %% [markdown]
# ### Gradient Boosting (Grid Search)

# %%
GB_cv = GradientBoostingClassifier()

n_estimators = [50,100,200,300]
param_grid = dict(n_estimators=n_estimators)

Best_params, Best_AUC, Best_classifier = cv_best_parameters(GB_cv,param_grid)
print("Best AUC = "+ str(Best_AUC))

print(Best_classifier)
# Out:
# Best AUC = 0.997769081719016
# GradientBoostingClassifier(n_estimators=300)

# %%
clf_GB = Best_classifier
clf_GB.fit(X_train_res,y_train_res)

scores_GB= evaluation_model(clf_GB, X_train_res, y_train_res, X_test, y_test, train=True)
# Out:
# Train Result:
#
# Confusion Matrix:
#  [[41351   128]
#  [ 1276 40203]]
#
# Accuracy Score: 0.9831
#
# Classification Report:
#                      precision    recall  f1-score   support
#
# Non-Defaulted Loan       0.97      1.00      0.98     41479
#     Defaulted Loan       1.00      0.97      0.98     41479
#
#           accuracy                           0.98     82958
#          macro avg       0.98      0.98      0.98     82958
#       weighted avg       0.98      0.98      0.98     82958
#
#
# Repeated Stratified KFold Cross Validation:
#
# Mean AUC (cv): 	 0.9971
# SD AUC: 		 0.0067

# %%
auc_ruc(X_test, y_test, 'ROC curve (Gradient Boosting)', clf_GB)
# Out:
# AUC= 0.9782208848989671

# %% [markdown]
# ### Model Performance

# %%
name_list = ['baseline','KNN','Logistic Regression', 'Naive Bayes', 'Random Forest', 'Gradient Boosting']
model_load = [model_baseline_res, clf_knn, clf_LR, clf_NB, clf_RF, clf_GB]

# %%
fpr_list = dict()
tpr_list = dict()
auc_list = dict()
precision_list = dict()
recall_list = dict()
auc_pr_list = dict()
for i,j in enumerate(name_list):
    print(i,j)
    print(model_load[i])
    y_pred = model_load[i].predict_proba(X_test)[:,1]
    fpr_list[j], tpr_list[j], _ = roc_curve(y_test, y_pred)
    auc_list[j]=roc_auc_score(y_test, y_pred)
    precision_list[j], recall_list[j], _ = precision_recall_curve(y_test, y_pred)
    auc_pr_list[j] = auc(recall_list[j], precision_list[j])
# Out:
# 0 baseline
# DummyClassifier(strategy='stratified')
# 1 KNN
# KNeighborsClassifier(n_neighbors=10)
# 2 Logistic Regression
# LogisticRegression(C=100)
# 3 Naive Bayes
# BernoulliNB(alpha=0.1)
# 4 Random Forest
# RandomForestClassifier(n_estimators=200, random_state=42)
# 5 Gradient Boosting
# GradientBoostingClassifier(n_estimators=300)

# %%
color_rgb =[(114,158,206), (255,158,74), (103,191,92),(237,102,93),(173,139,201),(205,204,93),(65,68,81)]
color_hex=['#729ece','#ff9e4a','#67bf5c','#ed665d','#ad8bc9','#cdcc5d','#414451']
'#%02x%02x%02x' % (205,204,93)
# Out:
# '#cdcc5d'

# %%
print(name_list)
# Out:
# ['baseline', 'KNN', 'Logistic Regression', 'Naive Bayes', 'Random Forest', 'Gradient Boosting']

# %%
# Plotting the bars
fig, (ax1,ax2) = plt.subplots(1,2, figsize=(12,5))

plt.rcParams.update({'font.size': 14})
#plt.figure(figsize=(6,6))
#color_hex=['#729ece','#ff9e4a','#67bf5c','#ed665d','#ad8bc9','#414451']
for i,j in enumerate(name_list[1:]):
    print(j, color_hex[i])
    ax1.plot(fpr_list[j], tpr_list[j], color=color_hex[i],label=j, lw=2.5)

ax1.plot([0, 1], [0, 1], color=color_hex[6], lw=2.5, linestyle='--', label='Baseline')

ax1.set_xlim([0.0, 1.0])
ax1.set_ylim([0.0, 1.0])
ax1.set_xlabel('False Positive Rate')
ax1.set_ylabel('True Positive Rate')
ax1.set_title('ROC curve') #Receiver Operating Characteristic 
ax1.legend(loc="lower right")

ax2.barh(list(auc_list.keys())[1:],list(auc_list.values())[1:])
ax2.axvline(list(auc_list.values())[0], color=color_hex[6], lw=2, linestyle='--', label='Baseline')
ax2.set_xlabel('AUC')
ax2.set_title('Model Performance')
ax2.legend(loc="lower left")

plt.tight_layout()
# Out:
# KNN #729ece
# Logistic Regression #ff9e4a
# Naive Bayes #67bf5c
# Random Forest #ed665d
# Gradient Boosting #ad8bc9

# %%
# Plotting the bars
fig, (ax1,ax2) = plt.subplots(1,2, figsize=(12,5))

plt.rcParams.update({'font.size': 14})

no_skill = len(y_test[y_test==1])/len(y_test) # postive class rationo_skill
ax1.plot([0,1],[no_skill, no_skill], color=color_hex[6], lw=2.5, linestyle='--', label='Baseline')

for i,j in enumerate(name_list[1:]):
    print(j, color_hex[i])
    ax1.plot(recall_list[j], precision_list[j], color=color_hex[i],label=j, lw=2.5)
    
ax1.set_xlim([0.0, 1.0])
ax1.set_ylim([0.0, 1.0])
ax1.set_xlabel('Recall')
ax1.set_ylabel('Precision')
ax1.set_title('ROC curve (Precision-Recall)') #Receiver Operating Characteristic 
ax1.legend(loc="best")

ax2.barh(list(auc_pr_list.keys())[1:],list(auc_pr_list.values())[1:])
ax2.axvline(no_skill , color=color_hex[6], lw=2, linestyle='--', label='Baseline')
ax2.set_xlabel('AUC (Precision-Recall)')
ax2.set_title('Model Performance')
ax2.legend()
plt.tight_layout()
# Out:
# KNN #729ece
# Logistic Regression #ff9e4a
# Naive Bayes #67bf5c
# Random Forest #ed665d
# Gradient Boosting #ad8bc9
